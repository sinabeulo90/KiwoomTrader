# %%
from trader import KWTrader

import sys
from PyQt5.QtWidgets import *

# %%
app = QApplication(sys.argv)

# %%
tr = KWTrader()
tr.initialize()

# %%
tr.connection()
# Out:
# on_event_connect
# 연결 성공

# %%
result = tr.opt10003("300120", "0", "0101")
# Out:
# Called OnReceiveTrData event! opt10003 opt10003
# GetCommDataEx opt10003 opt10003
# Ended OnReceiveTrData event!

# %%
print(result)
# Out:
# {'response': 0, 'screen_no': '0101', 'rq_name': 'opt10003', 'tr_code': 'opt10003', 'record_name': '', 'pre_next': '2', 'comm_data': {'header': ['시간', '현재가', '전일대비', '대비율', '우선매도호가단위', '우선매수호가단위', '체결거래량', 'sign', '누적거래량', '누적거래대금', '체결강도'], 'rows': [['155832', '-15350', '-600', '-3.76', '-15400', '-15350', '-60', '5', '174017', '2709119750', '54.12'], ['155121', '-15350', '-600', '-3.76', '-15400', '-15350', '-100', '5', '173957', '2708198750', '54.15'], ['154123', '-15350', '-600', '-3.76', '-15400', '-15350', '-10', '5', '173857', '2706663750', '54.20'], ['154000', '-15350', '-600', '-3.76', '-15400', '-15350', ' 138', '5', '173847', '2706510250', '54.21'], ['153021', '-15350', '-600', '-3.76', '-15400', '-15350', ' 6989', '5', '173709', '2704391950', '54.21'], ['151955', '-15350', '-600', '-3.76', '-15450', '-15350', '-3', '5', '166720', '2597110800', '54.21'], ['151955', '-15400', '-550', '-3.45', '-15450', '-15400', '-57', '5', '166717', '2597064750', '54.21'], ['151939', '-1545
# ...

# %%
tr.get_repeat_cnt("opt10003", "opt10003")
# Out:
# 0

# %%
위tr.get_data_count("우선매도호가다")
# Out:
# 0

# %%
위print(result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-cb0524aed5de> in <module>
# ----> 1 위print(result)
#
# NameError: name '위print' is not defined

# %%
print(result['comm_data'])
# Out:
# {u'record_name': u'', u'comm_data': [[u'155832', u'-15350', u'-600', u'-3.76', u'-15400', u'-15350', u'-60', u'5', u'174017', u'2709119750', u'54.12'], [u'155121', u'-15350', u'-600', u'-3.76', u'-15400', u'-15350', u'-100', u'5', u'173957', u'2708198750', u'54.15'], [u'154123', u'-15350', u'-600', u'-3.76', u'-15400', u'-15350', u'-10', u'5', u'173857', u'2706663750', u'54.20'], [u'154000', u'-15350', u'-600', u'-3.76', u'-15400', u'-15350', u' 138', u'5', u'173847', u'2706510250', u'54.21'], [u'153021', u'-15350', u'-600', u'-3.76', u'-15400', u'-15350', u' 6989', u'5', u'173709', u'2704391950', u'54.21'], [u'151955', u'-15350', u'-600', u'-3.76', u'-15450', u'-15350', u'-3', u'5', u'166720', u'2597110800', u'54.21'], [u'151955', u'-15400', u'-550', u'-3.45', u'-15450', u'-15400', u'-57', u'5', u'166717', u'2597064750', u'54.21'], [u'151939', u'-15450', u'-500', u'-3.13', u'-15450', u'-15400', u'+1', u'5', u'166660', u'2596186950', u'54.24'], [u'151935', u'-15450', u'-500', u'-3.13
# ...

# %%
A = []
A += [['a']]
A += [['b']]

# %%
print(A)
# Out:
# [['a'], ['b']]

# %%
A = {'header' : ['a'], 'rows' : [[]]}
A += {'header' : ['a'], 'rows' : [[]]}
print(A)
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-24-0e6f7af5615f> in <module>()
#       1 A = {'header' : ['a'], 'rows' : [[]]}
# ----> 2 A += {'header' : ['a'], 'rows' : [[]]}
#       3 print(A)
#
# TypeError: unsupported operand type(s) for +=: 'dict' and 'dict'

# %%
A
# Out:
# ['a', 'b']

# %%
kw = KWCore()
kw.init_connect_events()
