# %%
from PyQt5.QtWidgets import *
app = QApplication(sys.argv)

# %%
from core import Kiwoom
kw = Kiwoom()

# %%
# 1) CommConnect
kw.comm_connect()
# Out:
# on_event_connect
# 연결 성공

# %%
# 4) GetLoginInfo
print(kw.get_login_info("ACCOUNT_CNT"))
print(kw.get_login_info("ACCNO"))
print(kw.get_login_info("USER_ID"))
print(kw.get_login_info("USER_NAME"))
print(kw.get_login_info("KEY_BSECGB"))
print(kw.get_login_info("FIREW_SECGB"))
# Out:
# 1
# 8124691511;
# smbyun02
# 변성목
# 0
# 0

# %%
# 13) GetAPIModulePath
print(kw.get_api_module_path())
# Out:
# C:\OpenAPI

# %%
# 14) GetCodeListByMarket
print(kw.get_code_list_by_market(0))
print(kw.get_code_list_by_market(3))
print(kw.get_code_list_by_market(4))
print(kw.get_code_list_by_market(5))
print(kw.get_code_list_by_market(6))
print(kw.get_code_list_by_market(8))
print(kw.get_code_list_by_market(9))
print(kw.get_code_list_by_market(10))
print(kw.get_code_list_by_market(30))
print(kw.get_code_list_by_market(50))
# Out:
# 430', u'284980', u'284990', u'285000', u'285010', u'285020', u'285690', u'287180', u'287300', u'287310', u'287320', u'287330', u'289040', u'289250', u'289260', u'289480', u'289670', u'290080', u'290130', u'291130', u'291610', u'291620', u'291630', u'291660', u'291680', u'291890', u'292050', u'292100', u'292110', u'292120', u'292130', u'292140', u'292150', u'292160', u'292190', u'292340', u'292500', u'292560', u'292570', u'292580', u'292590', u'292730', u'292750', u'292770', u'293180', u'294400', u'295000', u'295020', u'295040', u'295820', u'295840', u'295860', u'295880', u'295890', u'296710', u'298340', u'298770', u'299070', u'299080', u'300280', u'300290', u'300300', u'300310', u'300610', u'300640', u'300950', u'301400', u'301410', u'301440', u'302170', u'302180', u'302190', u'302200', u'302210', u'302450', u'304660', u'304670', u'304760', u'304770', u'304780', u'304940', u'305050', u'305080', u'305540', u'305720', u'306520', u'306530', u'306540', u'306950', u'306960', u'307010', u'
# ...

# %%
# 15) GetConnectState
print(kw.get_connect_state())
# Out:
# 1

# %%
# 16) GetMarsterCodeName
print(kw.get_master_code_name("300120"))
# Out:
# 라온피플

# %%
# 17) GetMasterListedStockCnt
print(kw.get_master_listed_stock_cnt("300120"))
# Out:
# 10178456

# %%
# 18) GetMasterConstruction
print(kw.get_master_construction("300120"))
# Out:
# 정상

# %%
# 19) GetMasterListedStockDate
print(kw.get_master_listed_stock_date("300120"))
# Out:
# 20191018

# %%
# 20) GetMasterLastPrice
print(kw.get_master_last_price("300120"))
# Out:
# 00015950

# %%
# 21) GetMasterStockState
print(kw.get_master_stock_state("300120"))
# Out:
# 증거금40%

# %%
# 27) GetThemeGroupList
print(kw.get_theme_group_list(0))
print(kw.get_theme_group_list(1))
# Out:
# 100|태양광_폴리실리콘;101|태양광_잉곳/웨이퍼/셀/모듈;102|태양광_부품/소재/장비;103|태양광_발전/설치/운영;110|원자력_기자재;111|원자력_설계시공;120|화력_발전기자재;121|풍력_단조/기자재;130|바이오_디젤/에탄올;140|2차전지_완제품;141|2차전지_소재(양극화물질등);150|합성수지;151|합성섬유_원료;152|합성고무;153|탄소섬유;154|엔지니어링 플라스틱;160|금형/몰드베이스;170|강관;171|비철금속주;172|합금철;173|희소금속;180|제지_골판지;181|제지_기타;200|건설_해외건설;201|건설_국내주택;202|거푸집;203|시멘트;210|기계_건설기계;211|기계_공작기계;212|방위산업;213|로봇_지능형;214|우주항공;215|자원개발 E&P;220|조선_LNG보냉재;221|조선_해양플랜트기자재;222|조선_해양플랜트;223|조선_Eco선;230|운송_항공;231|운송_해운;232|운송_육상운송;240|자동차_차량경량화 수혜;241|자동차_전장화 수혜;242|자동차_블랙박스관련주;243|자동차_차량용 반도체;244|타이어;245|그린카_하이브리드카/전기차;250|가구;255|의복_아웃도어;256|의복_OEM;260|카지노;261|여행;262|전기자전거;270|교육;280|미디어_방송광고;281|미디어_디지털방송전환;282|컨텐츠_영상;283|컨텐츠_음원;284|컨텐츠_메니지먼트;285|컨텐츠_한류;286|에니메이션;290|백화점;291|홈쇼핑;300|주류;310|수산물/수산가공품;311|육계;312|곡물가공품_설탕/밀가루/유지;313|배합사료;314|유가공;315|빙과;316|라면;317|제과스낵;318|식자재유통;319|건강식품;330|화장품;350|의료기기_치아;351|의료기기;352|의료기기_안과;353|U-헬스케어;360|바이오_바이오시밀러/베터;361|바이오_줄기세포치료제;362|바이오_진단/백신;363|바이오_유전체분석;364|슈퍼박테리아;370|신약개발/기술수출;400|은행;410|창투;
# ...

# %%
# 29) GetFutureList
print(kw.get_future_list())
# Out:
# 101PC000;101Q3000;101Q6000;101Q9000;101QC000;101R6000;101RC000;401PCQ3S;401PCQ6S;401PCQ9S;401PCQCS;401PCR6S;401PCRCS;105PB000;105PC000;105Q1000;105Q2000;105Q3000;105Q4000;405PBPCS;405PBQ1S;405PBQ2S;405PBQ3S;405PBQ4S;106PC000;106Q3000;106Q6000;106Q9000;106QC000;106R6000;106RC000;406PCQ3S;406PCQ6S;406PCQ9S;406PCQCS;406PCR6S;406PCRCS;104PB000;104PC000;104Q1000;104Q2000;104Q3000;104Q4000;404PBPCS;404PBQ1S;404PBQ2S;404PBQ3S;404PBQ4S;107PC000;107Q3000;107Q6000;407PCQ3S;407PCQ6S;1A0PC000;1A0Q3000;1A0Q6000;1A0Q9000;1A0QC000;1A0R6000;1A0RC000;4A0PCQ3S;4A0PCQ6S;4A0PCQ9S;4A0PCQCS;4A0PCR6S;4A0PCRCS;1A1PC000;1A1Q3000;1A1Q6000;1A1Q9000;1A1QC000;1A1R6000;1A1RC000;4A1PCQ3S;4A1PCQ6S;4A1PCQ9S;4A1PCQCS;4A1PCR6S;4A1PCRCS;1A2PC000;1A2Q3000;1A2Q6000;1A2Q9000;1A2QC000;1A2R6000;1A2RC000;4A2PCQ3S;4A2PCQ6S;4A2PCQ9S;4A2PCQCS;4A2PCR6S;4A2PCRCS;1A3PC000;1A3Q3000;1A3Q6000;1A3Q9000;1A3QC000;1A3R6000;1A3RC000;4A3PCQ3S;4A3PCQ6S;4A3PCQ9S;4A3PCQCS;4A3PCR6S;4A3PCRCS;1A6PC000;1A6Q3000;1A6Q6000;1A6Q9000;1A6QC000;1A6R6000
# ...

# %%
# 30) GetFutureCodeByIndex
print(kw.get_future_code_by_index(0))
print(kw.get_future_code_by_index(1))
print(kw.get_future_code_by_index(2))
print(kw.get_future_code_by_index(3))
print(kw.get_future_code_by_index(4))
print(kw.get_future_code_by_index(5))
print(kw.get_future_code_by_index(6))
print(kw.get_future_code_by_index(7))
# Out:
# 101PC000
# 101Q3000
# 101Q6000
# 101Q9000
# 101QC000
# 101R6000
# 101RC000
# 401PCQ3S

# %%
# 31) GetActPriceList
print(kw.get_act_price_list())
# Out:
# 19000;19250;19500;19750;20000;20250;20500;20750;21000;21250;21500;21750;22000;22250;22500;22750;23000;23250;23500;23750;24000;24250;24500;24750;25000;25250;25500;25750;26000;26250;26500;26750;27000;27250;27500;27750;28000;28250;28500;28750;29000;29250;29500;29750;30000;30250;30500;30750;31000;31250;31500;31750;32000;32250;32500;32750;33000;33250;33500;33750;34000;34250;34500;34750;35000;35250;35500;35750;36000;36250;36500;36750;37000;37250;37500;37750;38000;38250;38500;38750;39000;39250;39500;39750;40000

# %%
# 32) GetMonthList
print(kw.get_month_list())
# Out:
# 202112;202106;202012;202009;202006;202004;202003;202002;202001;201912;201911;201911;201912;202001;202002;202003;202004;202006;202009;202012;202106;202112

# %%
# 43) GetSFOBasisAssetList
print(kw.get_s_fo_basis_asset_list())
# Out:
# KR7078340007|컴투스                                  ;KR7086900008|메디톡스                                ;KR7055550008|신한지주                                ;KR7079440004|오렌지라이프                            ;KR7091990002|셀트리온헬스케어                        ;KR7097950000|CJ제일제당                              ;KR7005830005|DB손해보험                              ;KR7008930000|한미사이언스                            ;KR7000810002|삼성화재                                ;KR7009830001|한화케미칼                              ;KR7000880005|한화                                    ;KR7005940002|NH투자증권                              ;KR7006800007|미래에셋대우                            ;KR7012330007|현대모비스                              ;KR7016360000|삼성증권                                ;KR7005930003|삼성전자                                ;KR7041510009|에스엠                                  ;KR7241560002|두산밥캣                                ;KR7192090009|TIGER 차이나CSI300                      ;KR7035900000|JYP Ent.                                ;K
# ...

# %%
# 44) GetOptionATM
print(kw.get_option_atm())
# Out:
# 28500

# %%
# 46) GetBranchCodeName
print(kw.get_branch_code_name())
